# %%
from train_model import cross_validation_training
results = cross_validation_training(
    cwt_data_path="C:\\Users\\aadel\\Desktop\\GCID\\Cuarto\\Segundo Cuatrimestre\\TFG\\python\\ml_data\\001_001_cwt_data.npz",
    output_dir='models/eegnext',
    n_folds=5,
    num_epochs=10
)
# Out:
# Loaded dataset:
#   Scalograms shape: (26, 3, 40, 2561)
#   Labels: [17  9]
#   Frequency range: 4.0 - 40.0 Hz
#   Time range: -10.0 - 0.0 s
#
# Using device: cpu
#
# ...
# FOLD 1/5
# ...
# Train samples: 20
# Val samples: 6
# Loading pretrained ConvNeXt-Tiny weights...
# Loaded 0 pretrained layers
#
# Epoch 1/10
# --------------------------------------------------
# ...
# Validation: 100%|██████████| 1/1 [00:25<00:00, 25.56s/it, loss=3.01]
# Train Loss: 0.7975 | Train Acc: 0.4000
# Val Loss: 3.0057 | Val Acc: 0.6667 | Val AUC: 0.3750
# ✓ Best model saved (AUC: 0.3750)
#
# Epoch 2/10
# --------------------------------------------------
# ...
# Validation: 100%|██████████| 1/1 [00:24<00:00, 24.26s/it, loss=1.86]
# Train Loss: 2.0045 | Train Acc: 0.6500
# Val Loss: 1.8611 | Val Acc: 0.6667 | Val AUC: 0.3750
#
# Epoch 3/10
# --------------------------------------------------
# ...
# Validation: 100%|██████████| 1/1 [00:22<00:00, 22.90s/it, loss=0.949]
# Train Loss: 0.0563 | Train Acc: 1.0000
# ...
